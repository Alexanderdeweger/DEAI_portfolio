# %%
import pandas as pd

from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import metrics

import matplotlib.pyplot as plt

# %%
# df = pd.read_excel("AmesHousing.xlsx")
# df
# Out:
#         ID  SalePrice Garage  Overall Qual  Gr Liv Area  Total Bsmt SF  \
# 0        1     215000    yes             6         1656         1080.0
# 1        2     105000    yes             5          896          882.0
# 2        3     172000    yes             6         1329         1329.0
# 3        4     244000    yes             7         2110         2110.0
# 4        5     189900    yes             5         1629          928.0
# ...    ...        ...    ...           ...          ...            ...
# 2925  2926     142500    yes             6         1003         1003.0
# 2926  2927     131000    yes             5          902          864.0
# 2927  2928     132000     no             5          970          912.0
# 2928  2929     170000    yes             5         1389         1389.0
# 2929  2930     188000    yes             7         2000          996.0
#
#       Lot Area  Year Built  Full Bath  Bedroom AbvGr Neighborhood House Style
# ...

# %%
# df = df.loc[:, ("SalePrice", 'House Style', 'Overall Qual', 'Garage')]
# df
# Out:
#       SalePrice House Style  Overall Qual Garage
# 0        215000      1Story             6    yes
# 1        105000      1Story             5    yes
# 2        172000      1Story             6    yes
# 3        244000      1Story             7    yes
# 4        189900      2Story             5    yes
# ...         ...         ...           ...    ...
# 2925     142500        SLvl             6    yes
# 2926     131000      1Story             5    yes
# 2927     132000      SFoyer             5     no
# 2928     170000      1Story             5    yes
# 2929     188000      2Story             7    yes
#
# [2930 rows x 4 columns]

# %%
# dummies_df = pd.get_dummies(df.loc[:, ("House Style")])
# dummies_df
# Out:
#       1.5Fin  1.5Unf  1Story  2.5Fin  2.5Unf  2Story  SFoyer   SLvl
# 0      False   False    True   False   False   False   False  False
# 1      False   False    True   False   False   False   False  False
# 2      False   False    True   False   False   False   False  False
# 3      False   False    True   False   False   False   False  False
# 4      False   False   False   False   False    True   False  False
# ...      ...     ...     ...     ...     ...     ...     ...    ...
# 2925   False   False   False   False   False   False   False   True
# 2926   False   False    True   False   False   False   False  False
# 2927   False   False   False   False   False   False    True  False
# 2928   False   False    True   False   False   False   False  False
# 2929   False   False   False   False   False    True   False  False
#
# [2930 rows x 8 columns]

# %%
# df = pd.concat([df, dummies_df], axis=1)
# df = df.drop(["House Style"], axis=1)
# # df = df.drop(["Neighborhood"], axis=1)

# df
# Out:
#       SalePrice  Overall Qual Garage  1.5Fin  1.5Unf  1Story  2.5Fin  2.5Unf  \
# 0        215000             6    yes   False   False    True   False   False
# 1        105000             5    yes   False   False    True   False   False
# 2        172000             6    yes   False   False    True   False   False
# 3        244000             7    yes   False   False    True   False   False
# 4        189900             5    yes   False   False   False   False   False
# ...         ...           ...    ...     ...     ...     ...     ...     ...
# 2925     142500             6    yes   False   False   False   False   False
# 2926     131000             5    yes   False   False    True   False   False
# 2927     132000             5     no   False   False   False   False   False
# 2928     170000             5    yes   False   False    True   False   False
# 2929     188000             7    yes   False   False   False   False   False
#
#       2Story  SFoyer   SLvl
# ...

# %%
# X = df.drop("Garage", axis=1)
# Y = df.loc[:, "Garage"]
# X
# Out:
#       SalePrice  Overall Qual  1.5Fin  1.5Unf  1Story  2.5Fin  2.5Unf  2Story  \
# 0        215000             6   False   False    True   False   False   False
# 1        105000             5   False   False    True   False   False   False
# 2        172000             6   False   False    True   False   False   False
# 3        244000             7   False   False    True   False   False   False
# 4        189900             5   False   False   False   False   False    True
# ...         ...           ...     ...     ...     ...     ...     ...     ...
# 2925     142500             6   False   False   False   False   False   False
# 2926     131000             5   False   False    True   False   False   False
# 2927     132000             5   False   False   False   False   False   False
# 2928     170000             5   False   False    True   False   False   False
# 2929     188000             7   False   False   False   False   False    True
#
#       SFoyer   SLvl
# ...

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(
#     X,
#     Y,
#     test_size=0.15,
#     random_state=42
# )

# %%
# dtree = DecisionTreeClassifier(max_depth=5)
# dtree = dtree.fit(X_train, Y_train)
# tree.plot_tree(dtree, feature_names=X.columns)
# plt.show()

# %%
# predicted_df = pd.DataFrame(dtree.predict(X_test))
# predicted_df = predicted_df.rename(columns= {0 : "Prediction"})
# model_results_frame = pd.concat([Y_test.reset_index()['Garage'], predicted_df], axis=1)
# model_results_frame
# Out:
#     Garage Prediction
# 0      yes        yes
# 1      yes        yes
# 2      yes        yes
# 3       no        yes
# 4      yes        yes
# ..     ...        ...
# 435    yes        yes
# 436    yes        yes
# 437    yes        yes
# 438    yes        yes
# 439    yes        yes
#
# [440 rows x 2 columns]

# %%
# confusionmatrix = metrics.confusion_matrix(model_results_frame["Garage"], model_results_frame["Prediction"])
# cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix= confusionmatrix, display_labels= [False, True])

# cm_display.plot()
# plt.show()

# %%
# metrics.accuracy_score(model_results_frame["Garage"], model_results_frame["Prediction"])
# Out:
# 0.9295454545454546

# %%
# metrics.recall_score(model_results_frame["Garage"], model_results_frame["Prediction"], pos_label='yes')
# Out:
# 0.9951100244498777

# %%
# metrics.precision_score(model_results_frame["Garage"], model_results_frame["Prediction"], pos_label='yes')
# Out:
# 0.9334862385321101

# %% [markdown]
# Logboek:
# poging 1 garage:
# SalePrice, Overall Qual en House Style
# max depth = 3
# acurracy ~93.4
# recall ~100
# precision ~93.4
#
# poging 2 garage:
# SalePrice, Gr Liv Area en House Style
# max depth = 3
# acurracy ~92
# recall ~98.8
# precision ~93
#
# poging 3 garage:
# SalePrice, Overall Qual, Gr Liv Area en House Style
# max depth = 3
# acurracy ~92
# recall ~98.8
# precision ~93.1
#
# poging 4 garage:
# SalePrice, Overall Qual, Gr Liv Area en House Style
# max depth = 2
# acurracy ~93
# recall ~100
# precision ~92.9

# %%
df2 = pd.read_excel("AmesHousing.xlsx")
df2
# Out:
#         ID  SalePrice Garage  Overall Qual  Gr Liv Area  Total Bsmt SF  \
# 0        1     215000    yes             6         1656         1080.0
# 1        2     105000    yes             5          896          882.0
# 2        3     172000    yes             6         1329         1329.0
# 3        4     244000    yes             7         2110         2110.0
# 4        5     189900    yes             5         1629          928.0
# ...    ...        ...    ...           ...          ...            ...
# 2925  2926     142500    yes             6         1003         1003.0
# 2926  2927     131000    yes             5          902          864.0
# 2927  2928     132000     no             5          970          912.0
# 2928  2929     170000    yes             5         1389         1389.0
# 2929  2930     188000    yes             7         2000          996.0
#
#       Lot Area  Year Built  Full Bath  Bedroom AbvGr Neighborhood House Style
# ...

# %%
df2 = df2.loc[:, ("Gr Liv Area", "Year Built", "SalePrice", "Neighborhood", "House Style", 'Bedroom AbvGr', 'Overall Qual')]
df2
# Out:
#       Gr Liv Area  Year Built  SalePrice Neighborhood House Style  \
# 0            1656        1960     215000        NAmes      1Story
# 1             896        1961     105000        NAmes      1Story
# 2            1329        1958     172000        NAmes      1Story
# 3            2110        1968     244000        NAmes      1Story
# 4            1629        1997     189900      Gilbert      2Story
# ...           ...         ...        ...          ...         ...
# 2925         1003        1984     142500      Mitchel        SLvl
# 2926          902        1983     131000      Mitchel      1Story
# 2927          970        1992     132000      Mitchel      SFoyer
# 2928         1389        1974     170000      Mitchel      1Story
# 2929         2000        1993     188000      Mitchel      2Story
#
#       Bedroom AbvGr  Overall Qual
# 0                 3             6
# 1                 2             5
# 2                 3             6
# ...

# %%
dummies_df = pd.get_dummies(df2.loc[:, ("Neighborhood", "House Style")])
dummies_df
# Out:
#       Neighborhood_Blmngtn  Neighborhood_Blueste  Neighborhood_BrDale  \
# 0                    False                 False                False
# 1                    False                 False                False
# 2                    False                 False                False
# 3                    False                 False                False
# 4                    False                 False                False
# ...                    ...                   ...                  ...
# 2925                 False                 False                False
# 2926                 False                 False                False
# 2927                 False                 False                False
# 2928                 False                 False                False
# 2929                 False                 False                False
#
#       Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# ...

# %%
df2 = pd.concat([df2, dummies_df], axis=1)
df2 = df2.drop(["House Style"], axis=1)
df2 = df2.drop(["Neighborhood"], axis=1)

df2
# Out:
#       Gr Liv Area  Year Built  SalePrice  Bedroom AbvGr  Overall Qual  \
# 0            1656        1960     215000              3             6
# 1             896        1961     105000              2             5
# 2            1329        1958     172000              3             6
# 3            2110        1968     244000              3             7
# 4            1629        1997     189900              3             5
# ...           ...         ...        ...            ...           ...
# 2925         1003        1984     142500              3             6
# 2926          902        1983     131000              2             5
# 2927          970        1992     132000              3             5
# 2928         1389        1974     170000              2             5
# 2929         2000        1993     188000              3             7
#
#       Neighborhood_Blmngtn  Neighborhood_Blueste  Neighborhood_BrDale  \
# ...

# %%
X = df2.drop("Overall Qual", axis=1)
Y = df2.loc[:, "Overall Qual"]
X
# Out:
#       Gr Liv Area  Year Built  SalePrice  Bedroom AbvGr  Neighborhood_Blmngtn  \
# 0            1656        1960     215000              3                 False
# 1             896        1961     105000              2                 False
# 2            1329        1958     172000              3                 False
# 3            2110        1968     244000              3                 False
# 4            1629        1997     189900              3                 False
# ...           ...         ...        ...            ...                   ...
# 2925         1003        1984     142500              3                 False
# 2926          902        1983     131000              2                 False
# 2927          970        1992     132000              3                 False
# 2928         1389        1974     170000              2                 False
# 2929         2000        1993     188000              3                 False
#
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.15,
    random_state=42
)

# %%
dtree = DecisionTreeClassifier(max_depth=10)
dtree = dtree.fit(X_train, Y_train)
# tree.plot_tree(dtree, feature_names=X.columns)
# plt.show()

# %%
predicted_df2 = pd.DataFrame(dtree.predict(X_test))
predicted_df2 = predicted_df2.rename(columns= {0 : "Prediction"})
model_results_frame = pd.concat([Y_test.reset_index()['Overall Qual'], predicted_df2], axis=1)
model_results_frame
# Out:
#      Overall Qual  Prediction
# 0               8           6
# 1               6           6
# 2               7           7
# 3               4           5
# 4               6           5
# ..            ...         ...
# 435             7           9
# 436             5           4
# 437             5           5
# 438             6           5
# 439             6           7
#
# [440 rows x 2 columns]

# %%
labels = sorted(set(model_results_frame["Overall Qual"]))

confusionmatrix = metrics.confusion_matrix(model_results_frame["Overall Qual"], model_results_frame["Prediction"], labels=labels)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix= confusionmatrix, display_labels= labels)

cm_display.plot()
plt.show()

# %%
metrics.accuracy_score(model_results_frame["Overall Qual"], model_results_frame["Prediction"])
# Out:
# 0.49318181818181817

# %%
metrics.recall_score(model_results_frame["Overall Qual"], model_results_frame["Prediction"], average='weighted', zero_division=0)
# Out:
# 0.49318181818181817

# %%
metrics.precision_score(model_results_frame["Overall Qual"], model_results_frame["Prediction"], average='weighted', zero_division=0)
# Out:
# 0.4993847059211845
